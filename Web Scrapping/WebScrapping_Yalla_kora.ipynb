# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
date = input("Please enter a Date in the following format MM/DD/YYYY: ")
# Out:
# Please enter a Date in the following format MM/DD/YYYY: 10/04/2023

# %%
print("You Choosed "+ date +" as a date")
# Out:
# You Choosed 10/04/2023 as a date

# %%
page = requests.get("https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={"+date+"}#")

# %%
matches_details = []

# %%
def get_match_info(championship):
    championship_title = championship.contents[1].find('h2').text.strip()
    all_matches = championship.contents[3].find_all('li')
    number_of_matches = len(all_matches)
    #all_matchesprint()
    print("There is " + str(number_of_matches) + " matches Today " + date + " in " + championship_title)
    for i in range(number_of_matches):
      #Get teams names
      team_A = all_matches[i].find('div',{'class' : 'teamA'}).text.strip()
      team_B = all_matches[i].find('div' ,{'class' : 'teamB'}).text.strip()
      #Get Score
      match_result = all_matches[i].find('div',{'class': 'MResult'}).find_all('span' , {'class': 'score'})
      score = f"{match_result[0].text.strip()} - {match_result[1].text.strip()}"
      #Get Match Time
      match_time = all_matches[i].find('div',{'class': 'MResult'}).find('span' , {'class': 'time'}).text.strip()
      #add match info to matches details
      matches_details.append({
          'نوع البطولة' : championship_title,
          'الفريق الأول' : team_A,
          'الفريق الثانى' : team_B,
          'التوقيت' : match_time,
          'النتيجة' : score
          })
    print(matches_details)

# %%
def main(page):
  src = page.content #to get the byte code of the page
  #print(src)
  print("-----------------------------------------")
  soup = BeautifulSoup(src , "lxml")
  #print(soup)
  print("-----------------------------------------")
  championship = soup.find_all("div" , {'class' : 'matchCard'})

  #print(championship)
  for i in range(len(championship)):
    get_match_info(championship[i])

  keys = matches_details[0].keys()
  print(keys)
  with open('matches_details.csv', 'w') as output_file:
    dict_writer = csv.DictWriter(output_file , keys)
    dict_writer.writeheader()
    dict_writer.writerows(matches_details)
    print("file Created Successfully")

# %%
main(page)
# Out:
# -----------------------------------------
# -----------------------------------------
# There is 12 matches Today 10/04/2023 in التصفيات المؤهلة للأولمبياد - كرة طائرة
# ...

# %%
# !pip install selenium

# %%
import requests
from bs4 import BeautifulSoup
import csv
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

chrome_options = Options()
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
service = Service(executable_path='/content/chromedriver.exe')
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
# d = webdriver.Chrome('/home/<user>/chromedriver',chrome_options)
# Out:
# ---------------------------------------------------------------------------
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[10], line 14
#      12 service = Service(executable_path='/content/chromedriver.exe')
#      13 options = webdriver.ChromeOptions()
# ---> 14 driver = webdriver.Chrome(service=service, options=options)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     DesiredCapabilities.CHROME["browserName"],
#      47     "goog",
#      48     options,
#      49     service,
#      50     keep_alive,
#      51 )
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:51, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
# ...

# %%
page = requests.get("https://www.psychiatry.org/patients-families/adhd/expert-q-and-a/")

# %%
def adhd_main(page):
  src = page.content #to get the byte code of the page
  #print(src)
  print("-----------------------------------------")
  soup = BeautifulSoup(src , "lxml")
  print(soup)
  print("-----------------------------------------")
  articles = soup.find_all("div" , {'id' : 'divFAQ'})
  print(articles)
  # driver = webdriver.Chrome()
  # driver.get("https://www.psychiatry.org/patients-families/adhd/expert-q-and-a/")
  # soup = BeautifulSoup(driver.page_source, 'lxml')
  # print(soup)
  # articles = driver.find_elements_by_class_name('c-article__body--h2')
  # print(articles)

# %%
adhd_main(page)
